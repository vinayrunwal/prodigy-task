# %%
import pandas as pd

# Now this should work
df = pd.read_csv("API_SP.POP.TOTL_DS2_en_csv_v2_38144.csv", skiprows=4)
df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130075728.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2016         2017         2018         2019  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select the year and some countries (you can modify these)
selected_countries = ['India', 'China', 'United States', 'Indonesia', 'Brazil']
year = '2020'

# Filter the data for selected countries and the chosen year
data_2020 = df[df['Country Name'].isin(selected_countries)][['Country Name', year]]

# Rename columns for clarity
data_2020.columns = ['Country', 'Population']

# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(data=data_2020, x='Country', y='Population', palette='viridis')

plt.title(f'Total Population in {year} for Selected Countries')
plt.ylabel('Population')
plt.xlabel('Country')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# /var/folders/fg/5vs9y2115171hgr133tzmqsc0000gn/T/ipykernel_2671/2165552808.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data_2020, x='Country', y='Population', palette='viridis')
